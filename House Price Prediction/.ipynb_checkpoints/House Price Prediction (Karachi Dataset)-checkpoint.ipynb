# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('Karachi.csv')
df
# Out:
#                                                   title       price  \
# 0             600 Yard Bungalow For Sale In DHA Phase 6  11.5 Crore
# 1     3 BEDS LUXURY 125 SQ YARDS VILLA FOR SALE LOCA...  1.45 Crore
# 2     4 BEDS LUXURY SPORTS CITY VILLA FOR RENT BAHRI...  2.12 Crore
# 3     3 BEDS LUXURY 235 SQ YARDS VILLA FOR SALE LOCA...   1.5 Crore
# 4                   Buying A Flat In Clifton - Block 9?     4 Crore
# ...                                                 ...         ...
# 8409  Construct Your Precinct 9, Bahria Hills 500 Sq...     5 Crore
# 8410  125 Square Yards House Up For Sale In Bahria T...   1.2 Crore
# 8411  235 Square Yards House Up For Sale In Bahria T...  1.55 Crore
# 8412  950 Square Feet's Apartments Up For Sale In Ba...     70 Lakh
# 8413  Ideal Location Ali Block Villa A Construction ...     1 Crore
#
#         date added   type  bedrooms  bathrooms         area  \
# 0     14 hours ago  House         5          6  600 Sq. Yd.
# ...

# %%
df = df.drop(columns=['description', 'keywords', 'url','date added'])

# %%
import pandas as pd
import numpy as np

def convert_price(price):
    if isinstance(price, float) or pd.isna(price):  
        return np.nan  
    
    price = str(price).strip() 

    if "Crore" in price:
        return float(price.replace(" Crore", "")) * 10000000  
    elif "Lakh" in price:
        return float(price.replace(" Lakh", "")) * 100000   
    else:
        return float(price)  
df['price'] = df['price'].apply(convert_price)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}  # Dictionary to store the encoders

# Iterate through columns to apply LabelEncoder only to categorical columns
for col in df.columns:
    if df[col].dtype == 'object':  # Check if the column is categorical
        # If the column has mixed data types (strings + numbers), convert to string
        df[col] = df[col].astype(str)
        
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])  # Encode column
        label_encoders[col] = le  # Store encoder for later use

df
# Out:
#       title  price  type  bedrooms  bathrooms  area  location  \
# 0      2007    503     3         5          6   273         3
# 1      1084    158     3         0          0     0         1
# 2      1475    215     3         0          0     0         1
# 3      1088    163     3         0          0     0         1
# 4      3390    303     2         3          3   104         2
# ...     ...    ...   ...       ...        ...   ...       ...
# 8409   3627    344     3         5          5   246         1
# 8410    385    140     3         4          4    42         1
# 8411    966    168     3         3          3   130         1
# 8412   2161     68     2         2          2    23         1
# 8413   4981    120     3         4          4    42         1
#
#       complete location
# 0                    96
# 1                    24
# 2                    22
# 3                    59
# 4                    83
# ...                 ...
# 8409                 69
# ...

# %%
# Check for missing values
df.fillna(0, inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate correlation matrix
correlation_matrix = df.corr()

# Plot correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
print(df.dtypes)
# Out:
# title                int64
# price                int64
# type                 int64
# bedrooms             int64
# bathrooms            int64
# area                 int64
# location             int64
# complete location    int64
# dtype: object
